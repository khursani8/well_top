# %%
# import libraries
import pandas as pd
import numpy as np

# our helper function
from helper import *

# %%
# change pandas display options
pd.options.display.max_columns = 100

# %%
# read data
data = pd.read_csv('../data/synth_inputs/cheal-a10.csv')

# %%
data.head()
# Out:
#         tvdss     BS  CALI  DENS  DRHO  DTC  GR  NEUT  PEF  RESD  RESM  RESS  \
# 0 -186.439881  12.25   NaN   NaN   NaN  NaN NaN   NaN  NaN   NaN   NaN   NaN
# 1 -186.287886  12.25   NaN   NaN   NaN  NaN NaN   NaN  NaN   NaN   NaN   NaN
# 2 -186.134892  12.25   NaN   NaN   NaN  NaN NaN   NaN  NaN   NaN   NaN   NaN
# 3 -185.982897  12.25   NaN   NaN   NaN  NaN NaN   NaN  NaN   NaN   NaN   NaN
# 4 -185.830902  12.25   NaN   NaN   NaN  NaN NaN   NaN  NaN   NaN   NaN   NaN
#
#    SP   fm       well  DTS  GR_CORR  NEUT_CORR  RESD_CORR  RESS_CORR  TEMP  \
# 0 NaN  NaN  cheal-a10  NaN      NaN        NaN        NaN        NaN   NaN
# 1 NaN  NaN  cheal-a10  NaN      NaN        NaN        NaN        NaN   NaN
# 2 NaN  NaN  cheal-a10  NaN      NaN        NaN        NaN        NaN   NaN
# 3 NaN  NaN  cheal-a10  NaN      NaN        NaN        NaN        NaN   NaN
# 4 NaN  NaN  cheal-a10  NaN      NaN        NaN        NaN        NaN   NaN
#
#    TENS        lat         lon
# 0   NaN -39.387038  174.304239
# 1   NaN -39.387038  174.304239
# 2   NaN -39.387038  174.304239
# 3   NaN -39.387038  174.304239
# 4   NaN -39.387038  174.304239

# %%
# make a copy to the original
data2 = data.copy()

# %%
# apply shale cutoff
data2['shale_cutoff'] = data2.GR.map(lambda x: 'sand' if x<=110 else np.nan if np.isnan(x) else 'shale')

# %%
plotter(
    data = data2.dropna(axis=0, how='any', subset=['shale_cutoff']),
    depth_col = [0],
    num_col = [6, 3, 7, 8],
    cat_col = [-1],
    cat_classes = [['shale','sand']],
    base_cmap='seismic',
    figsize=(12, 80)
)
